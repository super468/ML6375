# %%
X=[[1.,0.],[0.,0.],[1.,1.],[0.,1.]]
y=[1,0,0,1]

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(3,2),activation='logistic',solver='lbfgs',alpha=1e-6)

# %%
mlp.fit(X,y)
# Out:
# MLPClassifier(activation='logistic', alpha=1e-06, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(3, 2), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='lbfgs', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
mlp.loss_
# Out:
# 0.00023429449717907272

# %%
mlp.coefs_
# Out:
# [array([[-10.06925317,  -3.27454771,  -1.48086906],
#         [-15.2460576 ,  -2.26591233,  -2.07083604]]),
#  array([[ -9.43036472,  14.53560919],
#         [  1.14762739, -15.33131541],
#         [ -0.11037107,  -1.00823802]]),
#  array([[ -2.0868292 ],
#         [-26.19425212]])]

# %%
mlp.intercepts_
# Out:
# [array([ 3.50007092,  2.95012454, -3.81005295]),
#  array([ 2.2893021 ,  2.38754685]),
#  array([ 12.44206412])]

# %%
print(mlp.predict([[0.,0.]]))
# Out:
# [0]

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
names=['Sex','Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']
df=pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data",names=names)

# %%
encoder = preprocessing.LabelEncoder()
df["Sex"]=encoder.fit_transform(df["Sex"])

# %%
from sklearn.preprocessing import StandardScaler
columns=[i for i in names if i != 'Rings']
dfcopy=df.copy()
features=dfcopy[columns]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)
dfcopy[columns]=features
dfcopy
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1     1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2    -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3     1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4    -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
# 5    -0.064355 -0.824395 -1.087206 -1.064424     -0.973307       -0.983919
# 6    -1.280690  0.050033  0.071741  0.250672     -0.104505       -0.551363
# 7    -1.280690  0.174951  0.172519 -0.347099     -0.123880       -0.294533
# 8     1.151980 -0.408000 -0.381760 -0.347099     -0.651076       -0.643732
# 9    -1.280690  0.216591  0.323686  0.250672      0.134109       -0.202164
# 10   -1.280690  0.008394 -0.280982  0.011563     -0.453250       -0.745112
# ...

# %%
X=dfcopy[columns]
y=dfcopy['Rings']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(X_train)
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 2830 -1.280690  0.008394  0.222908 -0.107991      0.030098        0.329520
# 925  -0.064355 -0.782755 -0.835261 -0.944870     -0.946795       -0.909574
# 3845  1.151980 -0.574558 -0.583316 -0.825316     -0.841763       -0.887045
# 547   1.151980 -2.656529 -2.548487 -2.259966     -1.603495       -1.542638
# 2259 -1.280690  0.549706  0.575631  0.489780      0.554234        0.660696
# 3588  1.151980  1.049379  1.079522  1.087551      1.113041        1.760110
# 1450 -0.064355 -0.574558 -0.734483 -0.107991     -0.668411       -0.384648
# 2827 -0.064355 -0.199803 -0.331371 -0.466653     -0.611307       -0.612191
# 2233  1.151980  0.591345  0.676409  0.728888      0.546076        0.268692
# 611   1.151980 -2.739808 -2.649265 -2.140412     -1.624909       -1.574179
# 2337  1.151980  0.299870  0.474853  0.609334      0.063749        0.189840
# ...

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(200,100,100), random_state=1,max_iter=5000,activation='logistic',solver='lbfgs',alpha=0.4)
print(clf)
clf.fit(X_train, y_train)
print(clf.loss_)
print(clf.n_iter_)
# Out:
# MLPClassifier(activation='logistic', alpha=0.4, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200, 100, 100), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=5000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)
# 1.13201352938
# 5001

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score
train_pred=clf.predict(X_train)
print(accuracy_score(y_train,train_pred))
test_predictions = clf.predict(X_test)
print(accuracy_score(y_test,test_predictions))
#print(classification_report(y_test,predictions))
# Out:
# 0.959630516593
# 0.232854864434
